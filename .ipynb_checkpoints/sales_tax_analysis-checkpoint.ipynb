# %%
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import plotly.plotly as py
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
input_files = os.path.join('.','Resources','*.csv')
# files = [f for f in glob.glob(input_files)]
df_data=pd.concat([pd.read_csv(file)for file in glob.glob(input_files)])

df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40900 entries, 0 to 192
# Data columns (total 9 columns):
# State                    40900 non-null object
# ZipCode                  40900 non-null int64
# TaxRegionName            40900 non-null object
# StateRate                40900 non-null float64
# EstimatedCombinedRate    40900 non-null float64
# EstimatedCountyRate      40900 non-null float64
# EstimatedCityRate        40900 non-null float64
# EstimatedSpecialRate     40900 non-null float64
# RiskLevel                40900 non-null int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 3.1+ MB

# %%
df_data["ZipCode"]= df_data["ZipCode"].astype('str')
# 5-df_data["ZipCode"].apply(len)
df_data["ZipCode"] = df_data["ZipCode"].str.pad(5, side ='left', fillchar ='0')
# df_data[df_data["State"]=='PR']

# %%
states = [{'OH': 'Ohio', 'KY': 'Kentucky', 'AS': 'American Samoa', 'NV': 'Nevada', 'WY': 'Wyoming', 'NA': 'National', 'AL': 'Alabama', 'MD': 'Maryland', 'AK': 'Alaska', 'UT': 'Utah', 'OR': 'Oregon', 'MT': 'Montana', 'IL': 'Illinois', 'TN': 'Tennessee', 'DC': 'District of Columbia', 'VT': 'Vermont', 'ID': 'Idaho', 'AR': 'Arkansas', 'ME': 'Maine', 'WA': 'Washington', 'HI': 'Hawaii', 'WI': 'Wisconsin', 'MI': 'Michigan', 'IN': 'Indiana', 'NJ': 'New Jersey', 'AZ': 'Arizona', 'GU': 'Guam', 'MS': 'Mississippi', 'PR': 'Puerto Rico', 'NC': 'North Carolina', 'TX': 'Texas', 'SD': 'South Dakota', 'MP': 'Northern Mariana Islands', 'IA': 'Iowa', 'MO': 'Missouri', 'CT': 'Connecticut', 'WV': 'West Virginia', 'SC': 'South Carolina', 'LA': 'Louisiana', 'KS': 'Kansas', 'NY': 'New York', 'NE': 'Nebraska', 'OK': 'Oklahoma', 'FL': 'Florida', 'CA': 'California', 'CO': 'Colorado', 'PA': 'Pennsylvania', 'DE': 'Delaware', 'NM': 'New Mexico', 'RI': 'Rhode Island', 'MN': 'Minnesota', 'VI': 'Virgin Islands', 'NH': 'New Hampshire', 'MA': 'Massachusetts', 'GA': 'Georgia', 'ND': 'North Dakota', 'VA': 'Virginia'}]
states
df_states= pd.DataFrame(states).T

df_states.reset_index(inplace=True)
df_states.rename(columns={0:"State Name","index":"State"},inplace=True)
df_states
# df_data['State Name'] = df['State'].replace('\s*\d+]', '', regex=True)
# Out:
#    State                State Name
# 0     AK                    Alaska
# 1     AL                   Alabama
# 2     AR                  Arkansas
# 3     AS            American Samoa
# 4     AZ                   Arizona
# 5     CA                California
# 6     CO                  Colorado
# 7     CT               Connecticut
# 8     DC      District of Columbia
# 9     DE                  Delaware
# 10    FL                   Florida
# 11    GA                   Georgia
# 12    GU                      Guam
# 13    HI                    Hawaii
# 14    IA                      Iowa
# 15    ID                     Idaho
# 16    IL                  Illinois
# 17    IN                   Indiana
# 18    KS                    Kansas
# 19    KY                  Kentucky
# 20    LA                 Louisiana
# 21    MA             Massachusetts
# 22    MD                  Maryland
# 23    ME                     Maine
# 24    MI                  Michigan
# 25    MN                 Minnesota
# 26    MO                  Missouri
# 27    MP  Northern Mariana Islands
# 28    MS               Mississippi
# 29    MT                   Montana
# 30    NA                  National
# 31    NC            North Carolina
# 32    ND              North Dakota
# 33    NE                  Nebraska
# 34    NH             New Hampshire
# 35    NJ                New Jersey
# 36    NM                New Mexico
# 37    NV                    Nevada
# 38    NY                  New York
# 39    OH                      Ohio
# 40    OK                  Oklahoma
# 41    OR                    Oregon
# 42    PA              Pennsylvania
# 43    PR               Puerto Rico
# 44    RI              Rhode Island
# 45    SC            South Carolina
# 46    SD              South Dakota
# 47    TN                 Tennessee
# 48    TX                     Texas
# 49    UT                      Utah
# 50    VA                  Virginia
# 51    VI            Virgin Islands
# 52    VT                   Vermont
# 53    WA                Washington
# 54    WI                 Wisconsin
# 55    WV             West Virginia
# 56    WY                   Wyoming

# %%
df_data=df_data.merge(df_states,how="inner", on = "State")
df_data["Local Taxes"]=df_data["EstimatedCountyRate"] + df_data["EstimatedCityRate"] + df_data["EstimatedSpecialRate"]
df_data.head()
# Out:
#   State ZipCode TaxRegionName  StateRate  EstimatedCombinedRate  \
# 0    AK   99501  ALASKA STATE       0.00                   0.00
# 1    AK   99502  ALASKA STATE       0.00                   0.00
# 2    AK   99503  ALASKA STATE       0.00                   0.00
# 3    AK   99504  ALASKA STATE       0.00                   0.00
# 4    AK   99505  ALASKA STATE       0.00                   0.00
#
#    EstimatedCountyRate  EstimatedCityRate  EstimatedSpecialRate  RiskLevel  \
# 0                 0.00               0.00                  0.00          1
# 1                 0.00               0.00                  0.00          1
# 2                 0.00               0.00                  0.00          1
# 3                 0.00               0.00                  0.00          1
# 4                 0.00               0.00                  0.00          1
#
#   State Name  Local Taxes
# 0     Alaska         0.00
# 1     Alaska         0.00
# 2     Alaska         0.00
# 3     Alaska         0.00
# 4     Alaska         0.00

# %%
grp_by_state = df_data.groupby(["State","State Name"])

# %%
df_state_tax = grp_by_state[["StateRate"]].mean()
df_state_tax
# Out:
#                             StateRate
# State State Name
# AK    Alaska                     0.00
# AL    Alabama                    0.04
# AR    Arkansas                   0.06
# AZ    Arizona                    0.06
# CA    California                 0.06
# CO    Colorado                   0.03
# CT    Connecticut                0.06
# DC    District of Columbia       0.06
# DE    Delaware                   0.00
# FL    Florida                    0.06
# GA    Georgia                    0.04
# HI    Hawaii                     0.04
# IA    Iowa                       0.06
# ID    Idaho                      0.06
# IL    Illinois                   0.06
# IN    Indiana                    0.07
# KS    Kansas                     0.06
# KY    Kentucky                   0.06
# LA    Louisiana                  0.04
# MA    Massachusetts              0.06
# MD    Maryland                   0.06
# ME    Maine                      0.05
# MI    Michigan                   0.06
# MN    Minnesota                  0.07
# MO    Missouri                   0.04
# MS    Mississippi                0.07
# MT    Montana                    0.00
# NC    North Carolina             0.05
# ND    North Dakota               0.05
# NE    Nebraska                   0.05
# NH    New Hampshire              0.00
# NJ    New Jersey                 0.07
# NM    New Mexico                 0.05
# NV    Nevada                     0.05
# NY    New York                   0.04
# OH    Ohio                       0.06
# OK    Oklahoma                   0.05
# OR    Oregon                     0.00
# PA    Pennsylvania               0.06
# PR    Puerto Rico                0.11
# RI    Rhode Island               0.07
# SC    South Carolina             0.06
# SD    South Dakota               0.04
# TN    Tennessee                  0.07
# TX    Texas                      0.06
# UT    Utah                       0.05
# VA    Virginia                   0.04
# VT    Vermont                    0.06
# WA    Washington                 0.06
# WI    Wisconsin                  0.05
# WV    West Virginia              0.06
# WY    Wyoming                    0.04

# %% [markdown]
# # States with no state sales tax

# %%
# df_state_tax["Has State Tax"] = df_state_tax.apply(lambda x: True if x["StateRate"]==0.0 else False,axis=1)
df_state_tax["Has State Tax"] = df_state_tax["StateRate"]!=0.0 

df_state_tax[df_state_tax["Has State Tax"]==False][[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [(AK, Alaska), (DE, Delaware), (MT, Montana), (NH, New Hampshire), (OR, Oregon)]

# %% [markdown]
# # States with state sales tax

# %%
df_state_tax[df_state_tax["Has State Tax"]==True][["StateRate"]]
# Out:
#                             StateRate
# State State Name
# AL    Alabama                    0.04
# AR    Arkansas                   0.06
# AZ    Arizona                    0.06
# CA    California                 0.06
# CO    Colorado                   0.03
# CT    Connecticut                0.06
# DC    District of Columbia       0.06
# FL    Florida                    0.06
# GA    Georgia                    0.04
# HI    Hawaii                     0.04
# IA    Iowa                       0.06
# ID    Idaho                      0.06
# IL    Illinois                   0.06
# IN    Indiana                    0.07
# KS    Kansas                     0.06
# KY    Kentucky                   0.06
# LA    Louisiana                  0.04
# MA    Massachusetts              0.06
# MD    Maryland                   0.06
# ME    Maine                      0.05
# MI    Michigan                   0.06
# MN    Minnesota                  0.07
# MO    Missouri                   0.04
# MS    Mississippi                0.07
# NC    North Carolina             0.05
# ND    North Dakota               0.05
# NE    Nebraska                   0.05
# NJ    New Jersey                 0.07
# NM    New Mexico                 0.05
# NV    Nevada                     0.05
# NY    New York                   0.04
# OH    Ohio                       0.06
# OK    Oklahoma                   0.05
# PA    Pennsylvania               0.06
# PR    Puerto Rico                0.11
# RI    Rhode Island               0.07
# SC    South Carolina             0.06
# SD    South Dakota               0.04
# TN    Tennessee                  0.07
# TX    Texas                      0.06
# UT    Utah                       0.05
# VA    Virginia                   0.04
# VT    Vermont                    0.06
# WA    Washington                 0.06
# WI    Wisconsin                  0.05
# WV    West Virginia              0.06
# WY    Wyoming                    0.04

# %% [markdown]
# # Pie Chart

# %%
df_cnt = df_state_tax.groupby("Has State Tax").count()
df_cnt
plt.pie(df_cnt["StateRate"],labels=["No Sales Tax","Sales Tax"]  ,colors=['c','orange'] ,explode=[0.1,0],shadow=True,
       autopct="%1.2f%%")
plt.title("US States with sales tax vs without sales tax")
plt.show()
plt.tight_layout()

# %%
df_local_tax = grp_by_state[["Local Taxes"]].mean()
df_local_tax
# Out:
#                             Local Taxes
# State State Name
# AK    Alaska                       0.02
# AL    Alabama                      0.04
# AR    Arkansas                     0.02
# AZ    Arizona                      0.02
# CA    California                   0.02
# CO    Colorado                     0.03
# CT    Connecticut                  0.00
# DC    District of Columbia         0.00
# DE    Delaware                     0.00
# FL    Florida                      0.01
# GA    Georgia                      0.03
# HI    Hawaii                       0.00
# IA    Iowa                         0.01
# ID    Idaho                        0.00
# IL    Illinois                     0.01
# IN    Indiana                      0.00
# KS    Kansas                       0.02
# KY    Kentucky                     0.00
# LA    Louisiana                    0.05
# MA    Massachusetts                0.00
# MD    Maryland                     0.00
# ME    Maine                        0.00
# MI    Michigan                     0.00
# MN    Minnesota                    0.00
# MO    Missouri                     0.03
# MS    Mississippi                  0.00
# MT    Montana                      0.00
# NC    North Carolina               0.02
# ND    North Dakota                 0.01
# NE    Nebraska                     0.00
# NH    New Hampshire                0.00
# NJ    New Jersey                   0.00
# NM    New Mexico                   0.02
# NV    Nevada                       0.03
# NY    New York                     0.04
# OH    Ohio                         0.01
# OK    Oklahoma                     0.03
# OR    Oregon                       0.00
# PA    Pennsylvania                 0.00
# PR    Puerto Rico                  0.01
# RI    Rhode Island                 0.00
# SC    South Carolina               0.01
# SD    South Dakota                 0.01
# TN    Tennessee                    0.02
# TX    Texas                        0.01
# UT    Utah                         0.02
# VA    Virginia                     0.01
# VT    Vermont                      0.00
# WA    Washington                   0.02
# WI    Wisconsin                    0.00
# WV    West Virginia                0.00
# WY    Wyoming                      0.01

# %% [markdown]
# # States with no Local Taxes

# %%
df_local_tax["Has Local Tax"] = df_local_tax["Local Taxes"]!=0.0 

df_local_tax[df_local_tax["Has Local Tax"]==False][[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [(CT, Connecticut), (DC, District of Columbia), (DE, Delaware), (IN, Indiana), (KY, Kentucky), (MA, Massachusetts), (MD, Maryland), (ME, Maine), (MI, Michigan), (MT, Montana), (NH, New Hampshire), (NJ, New Jersey), (OR, Oregon), (RI, Rhode Island)]

# %% [markdown]
# # States with local taxes

# %%
df_local_tax[df_local_tax["Has Local Tax"]==True][["Local Taxes"]]
# Out:
#                       Local Taxes
# State State Name
# AK    Alaska                 0.02
# AL    Alabama                0.04
# AR    Arkansas               0.02
# AZ    Arizona                0.02
# CA    California             0.02
# CO    Colorado               0.03
# FL    Florida                0.01
# GA    Georgia                0.03
# HI    Hawaii                 0.00
# IA    Iowa                   0.01
# ID    Idaho                  0.00
# IL    Illinois               0.01
# KS    Kansas                 0.02
# LA    Louisiana              0.05
# MN    Minnesota              0.00
# MO    Missouri               0.03
# MS    Mississippi            0.00
# NC    North Carolina         0.02
# ND    North Dakota           0.01
# NE    Nebraska               0.00
# NM    New Mexico             0.02
# NV    Nevada                 0.03
# NY    New York               0.04
# OH    Ohio                   0.01
# OK    Oklahoma               0.03
# PA    Pennsylvania           0.00
# PR    Puerto Rico            0.01
# SC    South Carolina         0.01
# SD    South Dakota           0.01
# TN    Tennessee              0.02
# TX    Texas                  0.01
# UT    Utah                   0.02
# VA    Virginia               0.01
# VT    Vermont                0.00
# WA    Washington             0.02
# WI    Wisconsin              0.00
# WV    West Virginia          0.00
# WY    Wyoming                0.01

# %%
df_local = df_local_tax.groupby("Has Local Tax").count()
#df_local
plt.pie(df_local["Local Taxes"],labels=["No Local Sales Tax","Local Sales Tax"]  ,colors=['c','orange'] ,explode=[0.1,0],shadow=True,
       autopct="%1.2f%%")
plt.title("US States with local sales tax vs without local sales tax")
plt.show()
plt.tight_layout()

# %% [markdown]
# ### Top 5 States that have higher overall sales taxes

# %%
df_total_tax = grp_by_state[["EstimatedCombinedRate"]].mean()*100
df_total_tax.sort_values(by="EstimatedCombinedRate",ascending=False).head()
# Out:
#                    EstimatedCombinedRate
# State State Name
# PR    Puerto Rico                  11.47
# TN    Tennessee                     9.49
# LA    Louisiana                     9.14
# WA    Washington                    8.69
# AR    Arkansas                      8.62

# %% [markdown]
# ### Top 5 States that have lower overall sales taxes

# %%
df_total_tax.sort_values(by="EstimatedCombinedRate",ascending=True).head()
# Out:
#                      EstimatedCombinedRate
# State State Name
# OR    Oregon                          0.00
# NH    New Hampshire                   0.00
# MT    Montana                         0.00
# DE    Delaware                        0.00
# AK    Alaska                          1.89

# %%
df_total_tax.reset_index(inplace=True)
df_total_tax.head()
# Out:
#   State  State Name  EstimatedCombinedRate
# 0    AK      Alaska                   1.89
# 1    AL     Alabama                   8.02
# 2    AR    Arkansas                   8.62
# 3    AZ     Arizona                   7.91
# 4    CA  California                   8.30

# %%
for col in df_total_tax.columns:
    df_total_tax[col] = df_total_tax[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df_total_tax['text'] = df_total_tax['State'] + '<br>' +\
    'EstimatedCombinedRate '+df_total_tax['EstimatedCombinedRate']

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations =  df_total_tax['State'],
        z = df_total_tax['EstimatedCombinedRate']*100,
        locationmode = 'USA-states',
        text = df_total_tax['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Combined Tax Rate")
        ) ]

layout = dict(
        title = 'Combined Tax Rates by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~vikra8pc/1.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Average City Tax in each State

# %%
df_city_tax = grp_by_state[["EstimatedCityRate"]].mean()*100
df_city_tax.head()
# Out:
#                   EstimatedCityRate
# State State Name
# AK    Alaska                   1.50
# AL    Alabama                  1.85
# AR    Arkansas                 0.59
# AZ    Arizona                  1.55
# CA    California               0.16

# %%
df_city_tax.reset_index(inplace=True)

# %%
df_city_tax = df_city_tax[["State","State Name","EstimatedCityRate"]]
df_city_tax.sort_values("EstimatedCityRate",ascending=False).head()
# Out:
#    State State Name  EstimatedCityRate
# 36    OK   Oklahoma               2.30
# 1     AL    Alabama               1.85
# 5     CO   Colorado               1.78
# 18    LA  Louisiana               1.64
# 3     AZ    Arizona               1.55

# %%
df_city_tax.sort_values("EstimatedCityRate",ascending=False).tail()
df_city_tax.index
list(df_city_tax.loc[0,["State"]])
# Out:
# ['AK']

# %% [markdown]
# ### Bubble Plot of City Taxes in Each State

# %%
plt.figure(figsize=(25,25))
colors=cm.rainbow(np.random.rand(df_city_tax["State"].count()))
edgecolors=cm.rainbow(np.random.rand(df_city_tax["State"].count()))
plt.scatter(df_city_tax["State"],y=df_city_tax["State"], s=df_city_tax["EstimatedCityRate"]*1000,
            color=colors,edgecolor=edgecolors)
# for idx in df_city_tax.index:
#     plt.annotate(df_city_tax.loc[idx,["State Name"]],xy=(tuple(df_city_tax.loc[idx,["State"]],df_city_tax.loc[idx,["EstimatedCityRate"]])))
plt.xlabel('State')
plt.ylabel('City Tax rate')
plt.title('State wise City Tax rate')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Categorize states based on number of type of taxes and find the number of type of taxes are affecting the overall tax

# %%
df_tax_info = grp_by_state["EstimatedCombinedRate","StateRate","EstimatedCountyRate","EstimatedCityRate","EstimatedSpecialRate"].mean()
df_tax_info.head()
# Out:
#                   EstimatedCombinedRate  StateRate  EstimatedCountyRate  \
# State State Name
# AK    Alaska                       0.02       0.00                 0.00
# AL    Alabama                      0.08       0.04                 0.02
# AR    Arkansas                     0.09       0.06                 0.02
# AZ    Arizona                      0.08       0.06                 0.01
# CA    California                   0.08       0.06                 0.00
#
#                   EstimatedCityRate  EstimatedSpecialRate
# State State Name
# AK    Alaska                   0.01                  0.00
# AL    Alabama                  0.02                  0.00
# AR    Arkansas                 0.01                  0.00
# AZ    Arizona                  0.02                  0.00
# CA    California               0.00                  0.02

# %%
df_tax_info.reset_index(inplace=True)
df_tax_info.head()
# Out:
#   State  State Name  EstimatedCombinedRate  StateRate  EstimatedCountyRate  \
# 0    AK      Alaska                   0.02       0.00                 0.00
# 1    AL     Alabama                   0.08       0.04                 0.02
# 2    AR    Arkansas                   0.09       0.06                 0.02
# 3    AZ     Arizona                   0.08       0.06                 0.01
# 4    CA  California                   0.08       0.06                 0.00
#
#    EstimatedCityRate  EstimatedSpecialRate
# 0               0.01                  0.00
# 1               0.02                  0.00
# 2               0.01                  0.00
# 3               0.02                  0.00
# 4               0.00                  0.02

# %%
df_tax_info_cnt = df_tax_info.copy()
for col in df_tax_info_cnt.columns:
    if "Rate" in col:
        df_tax_info_cnt.loc[df_tax_info[col]>0 , col]=1
df_tax_info_cnt["TaxTypeCount"] = [ 
                              row.StateRate + row.EstimatedCountyRate
                               +row.EstimatedCityRate+row.EstimatedSpecialRate 
                               for index, row in df_tax_info_cnt.iterrows()
                              ] 

#     "StateRate","EstimatedCountyRate","EstimatedCityRate","EstimatedSpecialRate")
df_tax_info_cnt.head()
# Out:
#   State  State Name  EstimatedCombinedRate  StateRate  EstimatedCountyRate  \
# 0    AK      Alaska                   1.00       0.00                 1.00
# 1    AL     Alabama                   1.00       1.00                 1.00
# 2    AR    Arkansas                   1.00       1.00                 1.00
# 3    AZ     Arizona                   1.00       1.00                 1.00
# 4    CA  California                   1.00       1.00                 1.00
#
#    EstimatedCityRate  EstimatedSpecialRate  TaxTypeCount
# 0               1.00                  0.00          2.00
# 1               1.00                  1.00          4.00
# 2               1.00                  0.00          3.00
# 3               1.00                  1.00          4.00
# 4               1.00                  1.00          4.00

# %%
df_tax_info["TaxTypeCount"] = df_tax_info_cnt["TaxTypeCount"] 
df_tax_info.head()
# Out:
#   State  State Name  EstimatedCombinedRate  StateRate  EstimatedCountyRate  \
# 0    AK      Alaska                   0.02       0.00                 0.00
# 1    AL     Alabama                   0.08       0.04                 0.02
# 2    AR    Arkansas                   0.09       0.06                 0.02
# 3    AZ     Arizona                   0.08       0.06                 0.01
# 4    CA  California                   0.08       0.06                 0.00
#
#    EstimatedCityRate  EstimatedSpecialRate  TaxTypeCount
# 0               0.01                  0.00          2.00
# 1               0.02                  0.00          4.00
# 2               0.01                  0.00          3.00
# 3               0.02                  0.00          4.00
# 4               0.00                  0.02          4.00

# %%
grp_tax_cnt = df_tax_info.groupby("TaxTypeCount")

# %%
print(grp_tax_cnt["State"].count())
# Out:
# TaxTypeCount
# 0.00     4
# 1.00    10
# 2.00    11
# 3.00     9
# 4.00    18
# Name: State, dtype: int64

# %%
x=grp_tax_cnt["State"].count().index
y=grp_tax_cnt["State"].count()
fig,ax = plt.subplots(nrows=1, ncols=1,figsize=(10,5), squeeze=True)
ax.bar( x,y,color='g')
ax.set_title("No of Taxes vs state count",color='c')
ax.set_xlabel("Number of Taxes",color='b')
ax.set_ylabel("Number of States",color='b')
for val in range(0,5):
    ax.annotate(s=y[val],xy=(x[val],y[val]),color='r')
plt.show()

# %%
grp_tax_cnt["EstimatedCombinedRate"].mean()*100
# Out:
# TaxTypeCount
# 0.00   0.00
# 1.00   6.27
# 2.00   6.29
# 3.00   6.91
# 4.00   7.50
# Name: EstimatedCombinedRate, dtype: float64

# %% [markdown]
# ### Bar Graph showing the total salex tax variation  wrt no of type of taxes

# %%
x=grp_tax_cnt["EstimatedCombinedRate"].mean().index
y=grp_tax_cnt["EstimatedCombinedRate"].mean()*100
fig,ax = plt.subplots(nrows=1, ncols=1,figsize=(10,5), squeeze=True)
ax.bar( x,y,color='g')
ax.set_title("No of Taxes vs Total tax Rate",color='c')
ax.set_xlabel("Number of Taxes",color='b')
ax.set_ylabel("Total Tax Rate",color='b')
# s='{:.2f}'.format(y[val])
for val in range(0,5):
    ax.annotate(s='{:.2f}'.format(y[val]),xy=(x[val],y[val]),color='r')
plt.show()

# %%
# grp_tax_cnt.boxplot(by='TaxTypeCount', 
#                        column=['EstimatedCombinedRate'], 
#                        grid=False)
# plt.show()

# %% [markdown]
# ### Analysis of Puerto Rico (highest tax rate)

# %%
df_data_pr = df_data[df_data["State"]=="PR"]
df_data_pr.head()
# Out:
#       State ZipCode TaxRegionName  StateRate  EstimatedCombinedRate  \
# 31862    PR   00601   ADJUNTAS CO       0.10                   0.12
# 31863    PR   00602     AGUADA CO       0.10                   0.12
# 31864    PR   00603  AGUADILLA CO       0.10                   0.12
# 31865    PR   00604  AGUADILLA CO       0.10                   0.12
# 31866    PR   00605  AGUADILLA CO       0.10                   0.12
#
#        EstimatedCountyRate  EstimatedCityRate  EstimatedSpecialRate  \
# 31862                 0.01               0.00                  0.00
# 31863                 0.01               0.00                  0.00
# 31864                 0.01               0.00                  0.00
# 31865                 0.01               0.00                  0.00
# 31866                 0.01               0.00                  0.00
#
#        RiskLevel   State Name  Local Taxes
# 31862          1  Puerto Rico         0.01
# 31863          1  Puerto Rico         0.01
# 31864          1  Puerto Rico         0.01
# 31865          1  Puerto Rico         0.01
# 31866          1  Puerto Rico         0.01

# %% [markdown]
# ### Zip codes of PR with top 5 total tax rate

# %%
df_data_pr.sort_values(by="EstimatedCombinedRate",ascending=False ).head()
# Out:
#       State ZipCode TaxRegionName  StateRate  EstimatedCombinedRate  \
# 31862    PR   00601   ADJUNTAS CO       0.10                   0.12
# 31982    PR   00917   SAN JUAN CO       0.10                   0.12
# 31974    PR   00909   SAN JUAN CO       0.10                   0.12
# 31975    PR   00910   SAN JUAN CO       0.10                   0.12
# 31976    PR   00911   SAN JUAN CO       0.10                   0.12
#
#        EstimatedCountyRate  EstimatedCityRate  EstimatedSpecialRate  \
# 31862                 0.01               0.00                  0.00
# 31982                 0.01               0.00                  0.00
# 31974                 0.01               0.00                  0.00
# 31975                 0.01               0.00                  0.00
# 31976                 0.01               0.00                  0.00
#
#        RiskLevel   State Name  Local Taxes
# 31862          1  Puerto Rico         0.01
# 31982          1  Puerto Rico         0.01
# 31974          1  Puerto Rico         0.01
# 31975          1  Puerto Rico         0.01
# 31976          1  Puerto Rico         0.01
